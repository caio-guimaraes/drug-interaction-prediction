# %%
import pandas as pd

mimic_base_path = 'C:\\Users\\kai_o\\Documents\\workspace\\uff\\mimic-iii-clinical-database'

# %%
prescriptions_path = f'{mimic_base_path}\PRESCRIPTIONS.csv'
prescriptions = pd.read_csv(
    prescriptions_path,
    usecols=[
        "SUBJECT_ID",
        "HADM_ID",
        "DRUG",
        "STARTDATE",
        "ENDDATE"
    ]
)
